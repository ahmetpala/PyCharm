# %%
import sys
import glob
import numpy as np
import xarray as xr
import matplotlib as mp
import matplotlib.pyplot as plt
import holoviews as hv
import holoviews.operation.datashader as hd
import bokeh as bk

# %%
# Data Visualization

pred = xr.open_zarr('C:/Users/apa055/Desktop/Sampling Scripts/Data/preds.zarr', consolidated = False)
zarr = xr.open_dataset('C:/Users/apa055/Desktop/Sampling Scripts/Data/dataf.zarr', consolidated = False)

plt.figure(figsize = (25,25))
plt.imshow(10*np.log10(zarr.sv[0,:,:]).T.astype(float))
plt.colorbar(fraction=0.026, pad=0.01)
plt.xlabel('ping time')
plt.ylabel('range')
plt.title('38 kHz Sv')
plt.tight_layout()
plt.show()

zarr
# Out:
# C:\Users\apa055\AppData\Roaming\Python\Python38\site-packages\xarray\backends\plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# <xarray.Dataset>
# Dimensions:            (frequency: 6, ping_time: 1500, range: 700)
# Coordinates:
#     channel_id         (frequency) <U38 ...
#   * frequency          (frequency) float64 3.8e+04 1.8e+04 ... 2e+05 3.33e+05
#     latitude           (ping_time) float64 ...
#     longitude          (ping_time) float64 ...
#   * ping_time          (ping_time) datetime64[ns] 2019-04-25T14:10:58.907000 ...
#   * range              (range) float64 -0.19 0.0 0.19 ... 132.2 132.4 132.6
#     raw_file           (ping_time) <U29 ...
# Data variables:
#     angle_alongship    (frequency, ping_time, range) float32 ...
#     angle_athwartship  (frequency, ping_time, range) float32 ...
#     distance           (ping_time, frequency, range) float64 ...
# ...
